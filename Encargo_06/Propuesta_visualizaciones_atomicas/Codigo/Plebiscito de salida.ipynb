# %%
import matplotlib.pyplot as plt

# Datos
porcentajes = [38.11, 61.89]
etiquetas = ['Apruebo', 'Rechazo']
colores = ['green', 'red']

# Grafico
plt.barh(etiquetas, porcentajes, color=colores)

plt.xlabel('Porcentaje (%)')
plt.title('Resultado de la votación')

plt.show()
