# %%
# Importar librerías que nos ayudarán a usar funciones para limpiar los datos
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Lectura
from google.colab import drive
drive.mount('/gdrive')


ruta = "/gdrive/MyDrive/CSV2/Afiliacionesagosto2023.csv"
datos = pd.read_csv(ruta, sep=";")
print(datos.shape)
datos.head()
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# (23, 4)
#                Partido  Femenino  Masculino   Total
# 0   COMUNISTA DE CHILE    21.123     24.759  45.882
# 1  PARTIDO DE LA GENTE    13.815     28.313  42.128
# 2  SOCIALISTA DE CHILE    20.070     20.242  40.312
# 3  RENOVACION NACIONAL    21.117     18.278  39.395
# 4  CONVERGENCIA SOCIAL    18.170     18.597  36.767

# %% [markdown]
# En este primer paso importamos el archivo desde google drive e imprimimos los primeros 5 datos para corroborar que el documento haya sido leído sin problemas

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Partido    23 non-null     object
#  1   Femenino   23 non-null     float64
#  2   Masculino  23 non-null     float64
#  3   Total      23 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 864.0+ bytes

# %% [markdown]
# Corroboramos el número de filas y columnas, además de las categorias de cada columna

# %%
datos.dropna(inplace=True)
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Partido    23 non-null     object
#  1   Femenino   23 non-null     float64
#  2   Masculino  23 non-null     float64
#  3   Total      23 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 864.0+ bytes

# %% [markdown]
# Revisamos si hay datos faltantes

# %%
print(f'Tamaño del set antes de eliminar las filas repetidas: {datos.shape}')
datos.drop_duplicates(inplace=True)
print(f'Tamaño del set después de eliminar las filas repetidas: {datos.shape}')
# Out:
# Tamaño del set antes de eliminar las filas repetidas: (23, 4)
# Tamaño del set después de eliminar las filas repetidas: (23, 4)

# %% [markdown]
# Eliminamos las filas repetidas

# %%
datos= datos.drop(columns = ["Femenino", "Masculino"])
datos.head()
# Out:
#                Partido   Total
# 0   COMUNISTA DE CHILE  45.882
# 1  PARTIDO DE LA GENTE  42.128
# 2  SOCIALISTA DE CHILE  40.312
# 3  RENOVACION NACIONAL  39.395
# 4  CONVERGENCIA SOCIAL  36.767

# %% [markdown]
# Eliminamos los datos que no nos sirven.

# %%
datos.shape
# Out:
# (23, 2)

# %% [markdown]
# Esta son la nueva cantidad de columnas y filas.

# %%
ruta = "/gdrive/MyDrive/CSV2/datoslimpiosAGOSTO.csv"
datos.to_csv(ruta, index=False)

# %% [markdown]
# Creamos el nuevo archivo CSV con la limpieza de datos realizada
