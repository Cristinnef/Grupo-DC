# %%
# Importar librerías que nos ayudarán a usar funciones para limpiar los datos
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Lectura
from google.colab import drive
drive.mount('/gdrive')


ruta = "/gdrive/MyDrive/DATOS/probidadpartidospoliticos.csv"
data = pd.read_csv(ruta, sep=";")
print(data.shape)
data.head()
# Out:
# Mounted at /gdrive
# (358, 7)
#       Fecha Declaración           Nombre Apellido Paterno Apellido Materno  \
# 0  2019-04-05T00:00:00Z  HUMBERTO RAFAEL          BUROTTO          GUEVARA
# 1  2019-02-03T00:00:00Z     TOMÁS ANDRÉS          FUENTES           BARROS
# 2  2022-04-17T00:00:00Z      LUIS ARTURO          SQUELLA           OVALLE
# 3  2017-03-30T00:00:00Z     JAIME DANIEL         QUINTANA             LEAL
# 4  2018-03-28T00:00:00Z    DAVID OCTAVIO            GÓMEZ        CONTRERAS
#
#                       Cargo                             Tipo Declaración  \
# 0  MIEMBRO ÓRGANO EJECUTIVO  PRIMERA DECLARACIÓN (POR ASUNCIÓN DE CARGO)
# 1  MIEMBRO ÓRGANO EJECUTIVO  PRIMERA DECLARACIÓN (POR ASUNCIÓN DE CARGO)
# 2  MIEMBRO ÓRGANO EJECUTIVO  PRIMERA DECLARACIÓN (POR ASUNCIÓN DE CARGO)
# 3  MIEMBRO ÓRGANO EJECUTIVO  PRIMERA DECLARACIÓN (POR ASUNCIÓN DE CARGO)
# 4  MIEMBRO ÓRGANO EJECUTIVO  PRIMERA DECLARACIÓN (POR ASUNCIÓN DE CARGO)
#
#                     Institución
# 0   PARTIDO DEMÓCRATA CRISTIANO
# 1           RENOVACIÓN NACIONAL
# 2  PARTIDO REPUBLICANO DE CHILE
# 3     PARTIDO POR LA DEMOCRACIA
# 4                      AMPLITUD

# %% [markdown]
# En este primer paso importamos el archivo desde google drive e imprimimos los primeros 5 datos para corroborar que el documento haya sido leído sin problemas

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 358 entries, 0 to 357
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Fecha Declaración  358 non-null    object
#  1   Nombre             358 non-null    object
#  2   Apellido Paterno   358 non-null    object
#  3   Apellido Materno   358 non-null    object
#  4   Cargo              358 non-null    object
#  5   Tipo Declaración   358 non-null    object
#  6   Institución        358 non-null    object
# dtypes: object(7)
# memory usage: 19.7+ KB

# %% [markdown]
# Corroboramos el número de filas y columnas, además de las categorias de cada columna

# %%
data.dropna(inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 358 entries, 0 to 357
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Fecha Declaración  358 non-null    object
#  1   Nombre             358 non-null    object
#  2   Apellido Paterno   358 non-null    object
#  3   Apellido Materno   358 non-null    object
#  4   Cargo              358 non-null    object
#  5   Tipo Declaración   358 non-null    object
#  6   Institución        358 non-null    object
# dtypes: object(7)
# memory usage: 19.7+ KB

# %% [markdown]
# Revisamos si hay datos faltantes

# %%
print(f'Tamaño del set antes de eliminar las filas repetidas: {data.shape}')
data.drop_duplicates(inplace=True)
print(f'Tamaño del set después de eliminar las filas repetidas: {data.shape}')
# Out:
# Tamaño del set antes de eliminar las filas repetidas: (358, 7)
# Tamaño del set después de eliminar las filas repetidas: (353, 7)

# %% [markdown]
# Eliminamos las filas repetidas

# %%
data = data.drop(columns = ["Apellido Materno", "Cargo", "Tipo Declaración"])
data= data[data["Institución"]=="PARTIDO DEMÓCRATA CRISTIANO"]
data.head()
# Out:
#        Fecha Declaración           Nombre Apellido Paterno  \
# 0   2019-04-05T00:00:00Z  HUMBERTO RAFAEL          BUROTTO
# 12  2018-08-13T00:00:00Z  DAVID ALEJANDRO          MORALES
# 21  2018-08-31T00:00:00Z  HUMBERTO RAFAEL          BUROTTO
# 31  2018-08-20T00:00:00Z      LUIS FELIPE           DELPIN
# 38  2018-08-22T00:00:00Z     JOANNA ELENA            PÉREZ
#
#                     Institución
# 0   PARTIDO DEMÓCRATA CRISTIANO
# 12  PARTIDO DEMÓCRATA CRISTIANO
# 21  PARTIDO DEMÓCRATA CRISTIANO
# 31  PARTIDO DEMÓCRATA CRISTIANO
# 38  PARTIDO DEMÓCRATA CRISTIANO

# %% [markdown]
# Eliminamos los datos que no nos sirven.

# %%
data.shape
# Out:
# (14, 4)

# %% [markdown]
# Esta son la nueva cantidad de columnas y filas.

# %%
ruta = "/gdrive/MyDrive/DATOS/datoslimpios.csv"
data.to_csv(ruta, index=False)
print(datos)

# %% [markdown]
# Creamos el nuevo archivo CSV con la limpieza de datos realizada
