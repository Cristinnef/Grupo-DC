# %%
# Importar librerías que nos ayudarán a usar funciones para limpiar los datos
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Lectura
from google.colab import drive
drive.mount('/gdrive')



ruta = "/gdrive/MyDrive/CSV3/Resultados-Elecciones-de-Diputados-del-Partido-Demoìcrata-Cristiano.csv"
data = pd.read_csv(ruta, sep=",")
print(data.shape)
data.head()

ruta2 = "/gdrive/MyDrive/CSV3/Resultados-Elecciones-de-Senadores-del-Partido-Demoìcrata-Cristiano.csv"
data2 = pd.read_csv(ruta2, sep=",")
print(data2.shape)
data2.head()
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# (13, 4)
# (13, 4)
#    Año de elección Número de Votos      %  Número de Senadores
# 0             1961          90.211  14.07                    2
# 1             1965         633.251  46.36                   10
# 2             1969         345.248  32.71                    9
# 3             1973         467.248  36.18                   10
# 4             1989       2.188.329  32.18                   12

# %% [markdown]
# En este primer paso importamos el archivo desde google drive e imprimimos los primeros 5 datos para corroborar que el documento haya sido leído sin problemas

# %%
data.info()
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Año de elección      13 non-null     int64
#  1   Número de Votos      13 non-null     object
#  2   %                    13 non-null     float64
#  3   Número de Diputados  13 non-null     int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 544.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Año de elección      13 non-null     int64
#  1   Número de Votos      13 non-null     object
#  2   %                    13 non-null     float64
#  3   Número de Senadores  13 non-null     int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 544.0+ bytes

# %% [markdown]
# Corroboramos el número de filas y columnas, además de las categorias de cada columna

# %%
data.dropna(inplace=True)
data.info()
data2.dropna(inplace=True)
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Año de elección      13 non-null     int64
#  1   Número de Votos      13 non-null     object
#  2   %                    13 non-null     float64
#  3   Número de Diputados  13 non-null     int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 544.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Año de elección      13 non-null     int64
#  1   Número de Votos      13 non-null     object
#  2   %                    13 non-null     float64
#  3   Número de Senadores  13 non-null     int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 544.0+ bytes

# %% [markdown]
# Revisamos si hay datos faltantes

# %%
print(f'Tamaño del set antes de eliminar las filas repetidas: {data.shape}')
data.drop_duplicates(inplace=True)
print(f'Tamaño del set después de eliminar las filas repetidas: {data.shape}')
print(f'Tamaño del set antes de eliminar las filas repetidas: {data2.shape}')
data2.drop_duplicates(inplace=True)
print(f'Tamaño del set después de eliminar las filas repetidas: {data2.shape}')
# Out:
# Tamaño del set antes de eliminar las filas repetidas: (13, 4)
# Tamaño del set después de eliminar las filas repetidas: (13, 4)
# Tamaño del set antes de eliminar las filas repetidas: (13, 4)
# Tamaño del set después de eliminar las filas repetidas: (13, 4)

# %% [markdown]
# Eliminamos las filas repetidas

# %%
data= data.drop(columns = ["Número de Votos"])
data.head()
data2= data2.drop(columns = ["Número de Votos"])
data2.head()
# Out:
#    Año de elección      %  Número de Senadores
# 0             1961  14.07                    2
# 1             1965  46.36                   10
# 2             1969  32.71                    9
# 3             1973  36.18                   10
# 4             1989  32.18                   12

# %% [markdown]
# Eliminamos los datos que no nos sirven.

# %%
data.shape
data2.shape
# Out:
# (13, 3)

# %% [markdown]
# Esta son la nueva cantidad de columnas y filas.

# %%
ruta = "/gdrive/MyDrive/CSV3/Resultados-Elecciones-de-Diputados.csv"
data.to_csv(ruta, index=False)

ruta = "/gdrive/MyDrive/CSV3/Resultados-Elecciones-de-Senadores.csv"
data2.to_csv(ruta, index=False)
print(data)
print(data2)
# Out:
#     Año de elección      %  Número de Diputados
# 0              1961  15.40                   23
# 1              1965  42.30                   82
# 2              1969  29.80                   56
# 3              1973  28.70                   50
# 4              1989  25.99                   38
# 5              1993  27.12                   37
# 6              1997  22.98                   38
# 7              2001  18.92                   23
# 8              2005  20.76                   20
# 9              2009  14.21                   19
# 10             2013  15.55                   21
# 11             2017  10.28                   14
# 12             2021   4.17                    8
#     Año de elección      %  Número de Senadores
# 0              1961  14.07                    2
# 1              1965  46.36                   10
# 2              1969  32.71                    9
# 3              1973  36.18                   10
# 4              1989  32.18                   12
# ...

# %%
# Out:
# Mounted at /gdrive/

# %% [markdown]
# Creamos el nuevo archivo CSV con la limpieza de datos realizada
